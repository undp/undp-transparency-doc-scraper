# %%
import numpy as np
import pandas as pd
from fuzzywuzzy import process, fuzz
import time
import math
import re
from langdetect import detect

# %%
crs_file=pd.read_excel('../DAC-CRS-CODES-xlsx.xlsx', sheet_name='Purpose codes', header=3)
crs_file_fr=pd.read_excel('../DAC-CRS-CODES-xlsx.xlsx', sheet_name='Codes objet', header=3)

# %%
crs_file.columns = ['dac5','crs','voluntary', 'keywords','description','clarification']
crs_file_fr.columns = ['dac5','crs','voluntary','description_fr','clarification_fr']

# %%
crs_full_file = pd.merge(crs_file,crs_file_fr,how='left')

# %%
crs_full_file.loc[crs_full_file['dac5'].isnull() & crs_full_file['crs'].isnull(),'dac5'] = crs_full_file['voluntary']/100
crs_full_file.loc[crs_full_file['dac5'].isnull()==False & crs_full_file['crs'].isnull(),'crs'] = crs_full_file['voluntary']/10
crs_full_file.loc[crs_full_file['dac5'].isnull() & crs_full_file['voluntary'].isnull(),'dac5'] = crs_full_file['crs']/100

crs_full_file['dac5'] = crs_full_file['dac5'].apply(np.floor)
crs_full_file['crs'] = crs_full_file['crs'].apply(np.floor)

#get rid of 3 digit only rows
crs_full_file = crs_full_file[crs_full_file['crs'].isnull()==False]

# %%
crs_full_file['clarification'].replace("'",' ',inplace=True)
crs_full_file.loc[crs_full_file['clarification'].isnull(),'clarification'] = crs_full_file['description']
crs_full_file['description'] = crs_full_file['description'].str.lower()
crs_full_file['clarification'] = crs_full_file['clarification'].str.lower()

crs_full_file['clarification_fr'].replace("'",' ',inplace=True)
crs_full_file.loc[crs_full_file['clarification_fr'].isnull(),'clarification_fr'] = crs_full_file['description_fr']
crs_full_file['description_fr'] = crs_full_file['description_fr'].str.lower()
crs_full_file['clarification_fr'] = crs_full_file['clarification_fr'].str.lower()

crs_desc_l = crs_full_file['description'].str.lower().tolist()
crs_clari_l = crs_full_file['clarification'].str.lower().tolist()

crs_desc_l_fr = crs_full_file['description_fr'].str.lower().tolist()
crs_clari_l_fr = crs_full_file['clarification_fr'].str.lower().tolist()

# %%
#
crs_file.loc[crs_file['dac5'].isnull() & crs_file['crs'].isnull(),'dac5'] = crs_file['voluntary']/100
crs_file.loc[crs_file['dac5'].isnull()==False & crs_file['crs'].isnull(),'crs'] = crs_file['voluntary']/10
crs_file.loc[crs_file['dac5'].isnull() & crs_file['voluntary'].isnull(),'dac5'] = crs_file['crs']/100

crs_file_fr.loc[crs_file_fr['dac5'].isnull() & crs_file_fr['crs'].isnull(),'dac5'] = crs_file_fr['voluntary']/100
crs_file_fr.loc[crs_file_fr['dac5'].isnull()==False & crs_file_fr['crs'].isnull(),'crs'] = crs_file_fr['voluntary']/10
crs_file_fr.loc[crs_file_fr['dac5'].isnull() & crs_file_fr['voluntary'].isnull(),'dac5'] = crs_file_fr['crs']/100

# %%
#
crs_file['dac5'] = crs_file['dac5'].apply(np.floor)
crs_file['crs'] = crs_file['crs'].apply(np.floor)

crs_file_fr['dac5'] = crs_file_fr['dac5'].apply(np.floor)
crs_file_fr['crs'] = crs_file_fr['crs'].apply(np.floor)

# %%
#file to be analysed
####old: 
output_file = pd.read_excel('OECD_sector_review.xlsx', sheet_name='Sheet1')
output_file = output_file.head(200)
output_file.rename(columns = {'8.Description':'project_descr'}, inplace = True)
output_file.rename(columns = {'7.Project title':'project_title'}, inplace = True)
output_file.project_descr = output_file.project_descr.replace( np.nan, ' ').str.lower()
output_file.project_title = output_file.project_title.replace( np.nan, 'x ').str.lower()
output_file['project_descr_long'] = output_file['project_descr'].str.lower()

output_file_deduped = output_file

# %%
#new
output_file = pd.read_excel('output_list_2022_02_19.xlsx', sheet_name='Sheet1')
output_file['project_descr'] = output_file['project_descr'].str.lower()
output_file['project_title'] = output_file['project_title'].str.lower()
output_file['project_descr_long'] = output_file['project_descr_long'].str.lower()

# %%
output_file.head()
# Out:
#   hq_co bureau rollup_ou  project_num  output  \
# 0    CO    RBA       AGO        42722   49533
# 1    CO    RBA       AGO        78044   88535
# 2    CO    RBA       AGO        81003   90473
# 3    CO    RBA       AGO        84488   92469
# 4    CO    RBA       AGO        90310   96137
#
#                        project_title  \
# 0       organizational effectiveness
# 1      expansion  strengthening of a
# 2         ldcf/adaptation cuvelai rb
# 3  promotion of sustainable charcoal
# 4  strengthening national capacities
#
#                                        project_descr  \
# 0  the purpose of this project is to pay staff sa...
# 1  second gef intervention within a more comprehe...
# 2  promoting climate-resilient development and en...
# 3  the project aims to introduce energy-efficient...
# 4  the main goal of this project is to provide si...
#
#                                   project_descr_long      crs  \
# 0  the purpose of this project is to pay staff sa...  91010.0
# 1  1. operationalising the protected areas expans...  41010.0
# 2  the development of the province of cunene’s ca...  41010.0
# 3  1. information and strengthening of the policy...  41010.0
# 4  •\tstrengthen the national capacity in informa...  16050.0
#
#                                            crs_descr
# 0        Administrative costs (non-sector allocable)
# 1  Environmental policy and administrative manage...
# 2  Environmental policy and administrative manage...
# 3  Environmental policy and administrative manage...
# 4          Multisector aid for basic social services

# %%
output_file.project_descr = output_file.project_descr.replace( np.nan, ' ')
output_file.project_title = output_file.project_title.replace( np.nan, 'x ')

output_file_deduped = output_file

# %%
#output_file_deduped = output_file.loc[output_file['output'].duplicated()==False]
output_file.head(3)
# Out:
#   hq_co bureau rollup_ou  project_num  output                  project_title  \
# 0    CO    RBA       AGO        42722   49533   organizational effectiveness
# 1    CO    RBA       AGO        78044   88535  expansion  strengthening of a
# 2    CO    RBA       AGO        81003   90473     ldcf/adaptation cuvelai rb
#
#                                        project_descr  \
# 0  the purpose of this project is to pay staff sa...
# 1  second gef intervention within a more comprehe...
# 2  promoting climate-resilient development and en...
#
#                                   project_descr_long      crs  \
# 0  the purpose of this project is to pay staff sa...  91010.0
# 1  1. operationalising the protected areas expans...  41010.0
# 2  the development of the province of cunene’s ca...  41010.0
#
#                                            crs_descr
# 0        Administrative costs (non-sector allocable)
# 1  Environmental policy and administrative manage...
# 2  Environmental policy and administrative manage...

# %%
#
crs_file['clarification'].replace("'",' ',inplace=True)
crs_file.loc[crs_file['clarification'].isnull(),'clarification'] = crs_file['description']
crs_file['description'] = crs_file['description'].str.lower()
crs_file['clarification'] = crs_file['clarification'].str.lower()
crs_desc_l = crs_file['description'].str.lower().tolist()
crs_clari_l = crs_file['clarification'].str.lower().tolist()

crs_file_fr['clarification_fr'].replace("'",' ',inplace=True)
crs_file_fr.loc[crs_file_fr['clarification_fr'].isnull(),'clarification_fr'] = crs_file_fr['description_fr']
crs_file_fr['description_fr'] = crs_file_fr['description_fr'].str.lower()
crs_file_fr['clarification_fr'] = crs_file_fr['clarification_fr'].str.lower()
crs_desc_l_fr = crs_file_fr['description_fr'].str.lower().tolist()
crs_clari_l_fr = crs_file_fr['clarification_fr'].str.lower().tolist()

# %%
output_file_deduped['project_descr'][7].replace('development','').replace('designed','').replace('support','').replace('conference','').replace('project','')
# Out:
# 'this output aims to  the preparation of angolan women to actively participate and be effectively represented in the local governance elections of 2020 as candidates, mobilizers and influencers.'

# %%
process.extract(output_file_deduped['project_descr'][7].replace('development','').replace('designed','').replace('support','').replace('conference','').replace('project',''), crs_desc_l, scorer=fuzz.partial_ratio)
# Out:
# [('elections', 100),
#  ('coal', 75),
#  ('site preservation', 71),
#  ('education', 67),
#  ('local government finance', 67)]

# %%
crs_file.loc[any(ext in output_file_deduped['project_descr'][i] for ext in crs_file['keywords'].split(', ') )]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-70cc080eac88> in <module>
# ----> 1 crs_file.loc[any(ext in output_file_deduped['project_descr'][i] for ext in crs_file['keywords'].split(', ') )]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
crs_file['keywords'] = ' ' + crs_file['keywords']

# %%
crs_file.loc[crs_file.apply(lambda x:any(ext in output_file_deduped['project_descr'][i] for ext in str(x['keywords']).split(',') ) , axis=1)]
# Out:
#       dac5      crs  voluntary       keywords  \
# 103  151.0  15160.0        NaN   human rights
# 104  151.0  15170.0        NaN          women
# 105  151.0  15180.0        NaN   women, girls
# 201  250.0  25010.0        NaN      business,
#
#                                            description  \
# 103                                       human rights
# 104  women’s rights organisations and movements, an...
# 105            ending violence against women and girls
# 201                 business policy and administration
#
#                                          clarification
# 103  measures to support specialised official human...
# 104  support for feminist, women-led and women’s ri...
# 105  support to programmes designed to prevent and ...
# 201  public sector policies and institution support...

# %%
keyword_crs
# Out:
#       dac5      crs  voluntary    keywords  \
# 201  250.0  25010.0        NaN   business,
#
#                             description  \
# 201  business policy and administration
#
#                                          clarification
# 201  public sector policies and institution support...

# %%
start_time = time.perf_counter()
#english
for i in output_file_deduped.index.tolist()[0:100]:
#for i in output_file_deduped.index.tolist():
    
    #description checker agains desc
    try:
        if detect(output_file_deduped['project_descr'][i]) =='fr':
            keyword_crs = crs_desc_l_fr
            desc = keyword_crs
            desc_col = 'description_fr'
        else:
            #desc = crs_desc_l
            keyword_crs = crs_file.loc[crs_file.apply(lambda x:any(ext in output_file_deduped['project_descr'][i] for ext in str(x['keywords']).split(',') ) , axis=1)]
            if len(keyword_crs)>0:
                desc = keyword_crs['description'].str.lower().tolist()
            else:
                desc = crs_desc_l
            desc_col = 'description'
    except:
            keyword_crs = crs_file.loc[crs_file.apply(lambda x:any(ext in output_file_deduped['project_descr'][i] for ext in str(x['keywords']).split(',') ) , axis=1)]
            if len(keyword_crs)>0:
                desc = keyword_crs['description'].str.lower().tolist()
            else:
                desc = crs_desc_l
            desc_col = 'description'      
    
    result = process.extract(output_file_deduped['project_descr'][i].replace('development','').replace('designed',''), desc, scorer=fuzz.token_sort_ratio)
    df_result = pd.merge(crs_full_file,pd.DataFrame(result,columns=[desc_col,'descr_score']), 
             how='left', on=desc_col)

    #title checker agains desc
    try:
        if detect(output_file_deduped['project_title'][i]) =='fr':
            desc = crs_desc_l_fr
            desc_col = 'description_fr'
        else:
            desc = crs_desc_l
            desc_col = 'description'
    except:
            desc = crs_desc_l
            desc_col = 'description'        
    
    
    result = process.extract(output_file_deduped['project_title'][i].replace('development','').replace('designed',''), desc, scorer=fuzz.partial_ratio)
    df_result = pd.merge(df_result,pd.DataFrame(result,columns=[desc_col,'title_score']), 
             how='left', on=desc_col)
    
    #deduct score if title word not in description
    title_list =  re.sub("[^\w]", " ",  output_file_deduped['project_title'][i].lower()).split()
    df_result['title_score']=df_result.loc[df_result['title_score']>=0].apply(lambda y:  y['title_score'] if any(x in y['description'] for x in title_list) else y['title_score']*.5, axis=1)
    #extra points if title in description
    df_result['title_score']=df_result.loc[df_result['title_score']>=0].apply(lambda y:  y['title_score'] if any(x in y['clarification'] for x in title_list) else y['title_score']*1.1, axis=1)

    
    #evaluate project descr against clarification
    #description checker agains desc
    try:
        if detect(output_file_deduped['project_descr'][i]) =='fr':
            clari = crs_clari_l_fr
            clari_col = 'clarification_fr'
        else:
            clari = crs_clari_l
            clari_col = 'clarification'
    except:
            clari = crs_clari_l
            clari_col = 'clarification'        
        
    result = process.extract(output_file_deduped['project_descr'][i].replace('development','').replace('designed',''), clari, scorer=fuzz.token_sort_ratio)
    df_result = pd.merge(df_result,pd.DataFrame(result,columns=[clari_col,'descr_c_score']), 
             how='left', on=clari_col)
    
    if output_file_deduped['project_descr_long'][i]==output_file_deduped['project_descr_long'][i]:
        #long description checker agains desc
        try:
            if detect(output_file_deduped['project_descr_long'][i]) =='fr':
                clari = crs_clari_l_fr
                clari_col = 'clarification_fr'
            else:
                clari = crs_clari_l
                clari_col = 'clarification'
        except:
            clari = crs_clari_l
            clari_col = 'clarification'
            
        result = process.extract(output_file_deduped['project_descr_long'][i].replace('development','').replace('designed',''), clari, scorer=fuzz.token_set_ratio)
        df_result = pd.merge(df_result,pd.DataFrame(result,columns=[clari_col,'descr_l_score']), 
             how='left', on=clari_col)
    else:
        df_result['descr_l_score'] = math.nan

    df_result['total_score'] = df_result['descr_score'].fillna(0)*1.25 + df_result['title_score'].fillna(0)*.5 + \
                df_result['descr_l_score'].fillna(0)*.75 + df_result['descr_c_score'].fillna(0)

    #full board match get's 90% average weighting
    df_result.loc[(df_result['descr_score'].isnull() == False) & 
                  (df_result['descr_c_score'].isnull() == False) & 
                  (df_result['title_score'].isnull() == False) & 
                  (df_result['descr_l_score'].isnull() == False),'total_score'] = df_result['total_score']*.9

    #simple double occurance get's 70% average weighting
    df_result.loc[ (
                  ((df_result['descr_score'].isnull() == False) & 
                  (df_result['title_score'].isnull() == False)) |
                  ((df_result['title_score'].isnull() == False) &
                  (df_result['descr_score'].isnull() == False)) |
                  ((df_result['descr_score'].isnull() == False) &
                  (df_result['descr_l_score'].isnull() == False)) |
                  ((df_result['descr_score'].isnull() == False) &
                  (df_result['descr_c_score'].isnull() == False)) |
                  ((df_result['title_score'].isnull() == False) &
                  (df_result['descr_c_score'].isnull() == False)) |
                  ((df_result['descr_l_score'].isnull() == False) &
                  (df_result['descr_c_score'].isnull() == False)) ),'total_score'] = df_result['total_score']*.7

    df_result.loc[(df_result['crs'] == 32261),'total_score'] = df_result['total_score']*.5
    df_result.loc[(df_result['description'] == df_result['clarification']),'total_score'] = df_result['total_score']*.8
    
    #df_result.loc[(df_result['crs']>0) & 
     #         (df_result['crs']==output_file_deduped['crs'][i]) & 
      #        (df_result['crs']!=99810),'total_score'] = df_result['total_score']*1.35

    output_file_deduped.at[i,'dac5_result'] = df_result.loc[df_result['total_score'].argmax()]['dac5']
    output_file_deduped.at[i,'crs_result'] = df_result.loc[df_result['total_score'].argmax()]['crs']
    output_file_deduped.at[i,'volunt_result'] = df_result.loc[df_result['total_score'].argmax()]['voluntary']
    
    if math.isnan(df_result.loc[df_result['total_score'].argmax()]['voluntary'])==False:
        crs_final = df_result.loc[df_result['total_score'].argmax()]['voluntary']
    elif math.isnan(df_result.loc[df_result['total_score'].argmax()]['crs'])==False:
        crs_final = df_result.loc[df_result['total_score'].argmax()]['crs']
    elif math.isnan(df_result.loc[df_result['total_score'].argmax()]['dac5'])==False:
        crs_final = df_result.loc[df_result['total_score'].argmax()]['dac5']
    
    output_file_deduped.at[i,'crs_final'] = crs_final
    output_file_deduped.at[i,'crs_final_2ndplace'] = df_result.loc[df_result['total_score'].nlargest(2).index.tolist()[1]]['crs']
    output_file_deduped.at[i,'crs_final_2ndplace_desc'] = df_result.loc[df_result['total_score'].nlargest(2).index.tolist()[1]]['description']
    output_file_deduped.at[i,'crs_final_3rdplace'] = df_result.loc[df_result['total_score'].nlargest(3).index.tolist()[2]]['crs']
    output_file_deduped.at[i,'crs_final_3rdplace_desc'] = df_result.loc[df_result['total_score'].nlargest(3).index.tolist()[2]]['description']
    output_file_deduped.at[i,'crs_final_4thplace'] = df_result.loc[df_result['total_score'].nlargest(4).index.tolist()[3]]['crs']
    output_file_deduped.at[i,'crs_final_4thplace_desc'] = df_result.loc[df_result['total_score'].nlargest(4).index.tolist()[3]]['description']
    output_file_deduped.at[i,'crs_final_5thplace'] = df_result.loc[df_result['total_score'].nlargest(5).index.tolist()[4]]['crs']
    output_file_deduped.at[i,'crs_final_5thplace_desc'] = df_result.loc[df_result['total_score'].nlargest(5).index.tolist()[4]]['description']
    output_file_deduped.at[i,'crs_final_desc'] = df_result.loc[df_result['total_score'].argmax()]['description']
    output_file_deduped.at[i,'match_score'] = df_result.loc[df_result['total_score'].argmax()]['total_score']
    output_file_deduped.at[i,'title_score'] = df_result.loc[df_result['total_score'].argmax()]['title_score']
    output_file_deduped.at[i,'desc_score'] = df_result.loc[df_result['total_score'].argmax()]['descr_score']
    output_file_deduped.at[i,'desc_l_score'] = df_result.loc[df_result['total_score'].argmax()]['descr_l_score']
    output_file_deduped.at[i,'desc_c_score'] = df_result.loc[df_result['total_score'].argmax()]['descr_c_score']
    
print(time.perf_counter() - start_time, " seconds")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     495     try:
# --> 496         result = _convert_object_array(
#     497             content, columns, dtype=dtype, coerce_float=coerce_float
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     579             # caller's responsibility to check for this...
# --> 580             raise AssertionError(
#     581                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 2 columns passed, passed data had 3 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-a273d6100a9e> in <module>
#      26
#      27     result = process.extract(output_file_deduped['project_descr'][i].replace('development','').replace('designed',''), desc, scorer=fuzz.token_sort_ratio)
# ---> 28     df_result = pd.merge(crs_full_file,pd.DataFrame(result,columns=[desc_col,'descr_score']),
#      29              how='left', on=desc_col)
#      30
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     472                     if is_named_tuple(data[0]) and columns is None:
#     473                         columns = data[0]._fields
# --> 474                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     475                     columns = ensure_index(columns)
#     476
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     459         return [], []  # columns if columns is not None else []
#     460     if isinstance(data[0], (list, tuple)):
# --> 461         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     462     elif isinstance(data[0], abc.Mapping):
#     463         return _list_of_dict_to_arrays(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     498         )
#     499     except AssertionError as e:
# --> 500         raise ValueError(e) from e
#     501     return result
#     502
#
# ValueError: 2 columns passed, passed data had 3 columns

# %%
output_file_deduped.head(15)

# %%
output_file_deduped.loc[output_file_deduped['match_score']>=0]

# %%
output_file_deduped.to_csv('oecd_review_analysed_2022_02_19.csv')

# %%
output_file_deduped = pd.read_csv('oecd_review_analysed_2022_02_19.csv')

# %%
output_file_deduped.loc[output_file_deduped['project_descr'].str.contains('charcoal')==True,'crs']=23110

output_file_deduped.loc[output_file_deduped['project_descr'].str.contains('election')==True,'crs']=15150
output_file_deduped.loc[output_file_deduped['project_descr'].str.contains('human rights')==True,'crs']=15160
output_file_deduped.loc[output_file_deduped['project_descr'].str.contains('healthcare')==True,'crs']=13040
output_file_deduped.loc[output_file_deduped['project_descr'].str.contains('HIV')==True,'crs']=13040
output_file_deduped.loc[output_file_deduped['project_descr'].str.contains('AIDS')==True,'crs']=13040
output_file_deduped.loc[output_file_deduped['project_descr'].str.contains('uberculos')==True,'crs']=12263
output_file_deduped.loc[output_file_deduped['project_descr'].str.contains('alaria')==True,'crs']=12262
output_file_deduped.loc[output_file_deduped['project_descr'].str.contains('COVID')==True,'crs']=12264
output_file_deduped.loc[(output_file_deduped['project_descr'].str.contains('health')==True)
                        & (output_file_deduped['project_descr'].str.contains('training')==True),'crs']=12261

# %%
output_file_deduped.head(20)
# Out:
#     Unnamed: 0 hq_co bureau rollup_ou  project_num  output  \
# 0            0    CO    RBA       AGO        42722   49533
# 1            1    CO    RBA       AGO        78044   88535
# 2            2    CO    RBA       AGO        81003   90473
# 3            3    CO    RBA       AGO        84488   92469
# 4            4    CO    RBA       AGO        90310   96137
# 5            5    CO    RBA       AGO       103650  113597
# 6            6    CO    RBA       AGO       103650  113943
# 7            7    CO    RBA       AGO       103650  119528
# 8            8    CO    RBA       AGO       106462  107202
# 9            9    CO    RBA       AGO       106463  107203
# 10          10    CO    RBA       AGO       107733  107948
# 11          11    CO    RBA       AGO       107733  107949
# 12          12    CO    RBA       AGO       109372  108743
# 13          13    CO    RBA       AGO       109372  109188
# 14          14    CO    RBA       AGO       109372  110427
# 15          15    CO    RBA       AGO       109372  110431
# 16          16    CO    RBA       AGO       109372  116815
# 17          17    CO    RBA       AGO       109372  120340
# 18          18    CO    RBA       AGO       109627  108939
# 19          19    CO    RBA       AGO       110554  109747
#
#                                         project_title  \
# 0                        Organizational Effectiveness
# 1                       Expansion  Strengthening of A
# 2                          LDCF/Adaptation Cuvelai RB
# 3                   Promotion of Sustainable Charcoal
# 4                   Strengthening National Capacities
# 5                         Support for Local Elections
# 6                      Post-Elections Tech Assistance
# 7                          Women for Local Governance
# 8                        Procurement Support Services
# 9                        Implement Support for IFIGov
# 10       Inter-institutional Disaster Risk Management
# 11                   Info system early warning system
# 12                         Strengthening Human Rights
# 13                      Tech Assist Angolas Ombudsman
# 14                     Strengthen Legality in Eco Gov
# 15                      Gender and Womens Empowerment
# 16                          Tech Assistance to MININT
# 17                     TA for local protection of HRs
# 18               Second stage of HCFCs Phase-Out Plan
# 19  Technical Assistance to foster economic divers...
#
#                                         project_descr  \
# 0   The purpose of this project is to pay staff sa...
# 1   Second GEF intervention within a more comprehe...
# 2   Promoting climate-resilient development and en...
# 3   The Project aims to introduce energy-efficient...
# 4   The main goal of this project is to provide si...
# 5   Technical Assistance for Local Governance (TA-...
# 6   Post-Elections Technical Assistance to Angola ...
# 7   This output aims to support the preparation of...
# 8   Procurement of HIV health products using Gover...
# 9   Innovative development solutions and partnersh...
# 10  3.3.1 Promote the establishment and strengthen...
# 11  3.3.2 Develop and implement a risk information...
# 12  This output seeks to advance human rights in A...
# 13  This output aims to strengthen functional capa...
# 14  This output will support the countrys efforts ...
# 15  This output aims to contribute for the acceler...
# 16  This output aims to contribute to the enhancem...
# 17  This output will provide technical support for...
# 18  Second stage of HCFCs Phase-Out Plan for Angol...
# 19  Technical Assistance to foster economic divers...
#
#                                    project_descr_long      crs  ...  \
# 0   The purpose of this project is to pay staff sa...  91010.0  ...
# 1   1. Operationalising the Protected Areas expans...  41010.0  ...
# 2   The development of the Province of Cunene’s ca...  41010.0  ...
# 3   1. Information and strengthening of the policy...  23110.0  ...
# 4   •\tStrengthen the national capacity in informa...  13040.0  ...
# 5   The project aims to support the process of ins...  15151.0  ...
# 6   The project aims to contribute to the strength...  15151.0  ...
# 7   This output aims to contribute to the empowerm...  15150.0  ...
# 8   The project aims to strengthen the national HI...  13040.0  ...
# 9   1)\tAssess the key capacity needs of various s...  15144.0  ...
# 10  Planned interventions of this project output a...  73010.0  ...
# 11  Planned interventions of this project output a...  73010.0  ...
# 12  This output seeks to strengthen national human...  15160.0  ...
# 13  This output aims to support the Ombudsman inst...  15131.0  ...
# 14  This output aims to strengthen legality in eco...  15131.0  ...
# 15  This output builds on previous interventions o...  15160.0  ...
# 16  This output aims to contribute to the enhancem...  15160.0  ...
# 17  This involves the provision of technical assis...  15160.0  ...
# 18  The  objective of the project is to promote go...  41010.0  ...
# 19  The project aligns with the Partnership Framew...  15144.0  ...
#
#                               crs_final_4thplace_desc  crs_final_5thplace  \
# 0              other prevention and treatment of ncds             23231.0
# 1                                           ombudsman              1514.0
# 2                       livestock/veterinary services             32210.0
# 3                  national monitoring and evaluation              2201.0
# 4                                    judicial affairs             41082.0
# 5      anti-corruption organisations and institutions              1513.0
# 6                               sectors not specified             12310.0
# 7                                     budget planning             15151.0
# 8                                              police              2201.0
# 9   women’s rights organisations and movements, an...              1518.0
# 10      informal/semi-formal financial intermediaries             24050.0
# 11        water supply and sanitation - large systems             15153.0
# 12                 national monitoring and evaluation              1513.0
# 13                                   judicial affairs              1514.0
# 14                                          elections             93010.0
# 15  decentralisation and support to subnational go...             99810.0
# 16  refugees/asylum seekers  in donor countries (n...              9301.0
# 17                                      bio-diversity              1601.0
# 18  fossil fuel electric power plants with carbon ...             16040.0
# 19                                    budget planning              1512.0
#
#                               crs_final_5thplace_desc  \
# 0   solar energy for isolated grids and standalone...
# 1                      national standards development
# 2   mineral/mining policy and administrative manag...
# 3                                information services
# 4                              environmental research
# 5                                    judicial affairs
# 6                               ncds control, general
# 7                                           elections
# 8                                     postal services
# 9                     local government administration
# 10  remittance facilitation, promotion and optimis...
# 11                 media and free flow of information
# 12                                   judicial affairs
# 13                            meteorological services
# 14  refugees/asylum seekers  in donor countries (n...
# 15                              sectors not specified
# 16  refugees/asylum seekers in donor countries - a...
# 17  social protection and welfare services policy,...
# 18                                   low-cost housing
# 19                 national monitoring and evaluation
#
#                                        crs_final_desc  match_score  \
# 0                                 fishery development       57.750
# 1                    rural land policy and management       43.000
# 2                                information services       61.500
# 3      energy conservation and demand-side efficiency       65.100
# 4                                           ombudsman       45.000
# 5                                           elections       67.900
# 6                                           elections       70.700
# 7   women’s rights organisations and movements, an...       50.925
# 8                                   forestry services       70.400
# 9                                information services       58.500
# 10  women’s rights organisations and movements, an...       57.500
# 11                   urban land policy and management       71.925
# 12                                       human rights       92.000
# 13                                          ombudsman       66.500
# 14                            debt and aid management       51.000
# 15  women’s rights organisations and movements, an...       48.750
# 16  refugees/asylum seekers in donor countries - h...       52.500
# 17  personnel development for population and repro...       46.375
# 18  refugees/asylum seekers  in donor countries (n...       50.225
# 19  refugees/asylum seekers  in donor countries (n...       60.550
#
#     title_score desc_score  desc_l_score desc_c_score  COVID
# 0           NaN        NaN          50.0         45.0    NaN
# 1           NaN        NaN           NaN         43.0    NaN
# 2           NaN        NaN          82.0          NaN    NaN
# 3           NaN       40.0           NaN         43.0    NaN
# 4           NaN        NaN           NaN         45.0    NaN
# 5         110.0        NaN           NaN         42.0    NaN
# 6         110.0        NaN           NaN         46.0    NaN
# 7          58.0       35.0           NaN          NaN    NaN
# 8          80.0        NaN          64.0          NaN    NaN
# 9           NaN        NaN          78.0          NaN    NaN
# 10          NaN       46.0           NaN          NaN    NaN
# 11          NaN        NaN          69.0         51.0    NaN
# 12        100.0        NaN          56.0          NaN    NaN
# 13        110.0        NaN           NaN         40.0    NaN
# 14          NaN        NaN           NaN         51.0    NaN
# 15          NaN       39.0           NaN          NaN    NaN
# 16          NaN       42.0           NaN          NaN    NaN
# 17          NaN       25.0           NaN         35.0    NaN
# 18          NaN       27.0           NaN         38.0    NaN
# 19          NaN       34.0           NaN         44.0    NaN
#
# [20 rows x 30 columns]

# %%
output_file_deduped[output_file_deduped['project_descr'].str.contains('uberculos')==True]
# Out:
#       Unnamed: 0 hq_co bureau rollup_ou  project_num  output  \
# 30            30    CO    RBA       AGO       136333  128834
# 56            56    CO    RBA       BDI       129553  123180
# 423          423    CO    RBA       COG       129730  123299
# 793          793    CO    RBA       LBR       125917  123627
# 1776        1776    CO   RBAP       AFG       128299  122298
# 1777        1777    CO   RBAP       AFG       128299  129589
# 2047        2047    CO   RBAP       IDN       106768  127136
# 2300        2300    CO   RBAP       MMR        63637   80622
# 3173        3173    CO   RBAS       SDN       108620  108353
# 4271        4271    CO   RBEC       UKR        70648   84507
# 4276        4276    CO   RBEC       UKR        90474  112839
# 4298        4298    CO   RBEC       UKR        90474  118116
# 4302        4302    CO   RBEC       UKR        90474  118970
# 4343        4343    CO   RBEC       UZB       116580  113659
# 4466        4466    CO  RBLAC       BOL       122726  118214
# 5572        5572    CO  RBLAC       SLV        68118   83506
# 5584        5584    CO  RBLAC       SLV       115898  113302
# 5836        5836    HQ   BPPS       H70        74638  110751
# 5837        5837    HQ   BPPS       H70        75333  110744
#
#                                           project_title  \
# 30                                          C19 RM 2021
# 56                                            FM VIH/TB
# 423                       HIV, TB and Capacity Building
# 793                      PIP/UNDP/MOH/Global Fund Colla
# 1776                              HIV/AIDS, TB  Malaria
# 1777                                             CRM 19
# 2047                       TAA FOR IMPLEMENTATION GFATM
# 2300                        GLOBAL FUND SECRETARIAT CCM
# 3173                          Continuity of fighting TB
# 4271                             Strengthening Capacity
# 4276                                  TB Medicines 2018
# 4298                                  TB diagnosis 2019
# 4302                                  TB medicines 2019
# 4343                            Resilient Health System
# 4466                       Fort. acciones de control TB
# 5572                        Fortalecimiento Programa TB
# 5584                     El Salvador Plan Estratégico N
# 5836  Global Health Innovative Technology Research a...
# 5837                     Access and Delivery (Scale up)
#
#                                           project_descr  \
# 30    The Project seeks to mitigate the effects of t...
# 56    Le projet vise à soutenir les programmes natio...
# 423   La subvention est financée par le Fonds Mondia...
# 793   The PIP/UNDP/MOH/Global Fund Collaboration fra...
# 1776  HIV/AIDS, Tuberculosis  Malaria Programs and H...
# 1777  CRM 19, HIV/AIDS, Tuberculosis  Malaria Progra...
# 2047  UNDP Technical Cooperation for the HIV, Tuberc...
# 2300  GLOBAL FUND SECRETARIAT CCM FUNDING to support...
# 3173  To decrease Tuberculosis (TB) burden in Sudan ...
# 4271  The capacity of the National Council on Tuberc...
# 4276  Centralized procurement for the Ministry of He...
# 4298  Centralized procurement for the Ministry of He...
# 4302  Centralized procurement for the Ministry of He...
# 4343  Procurement support services to the Republican...
# 4466  Disminuir la alta carga de la tuberculosis y s...
# 5572  Fortalecimiento al Programa Nacional de Tuberc...
# 5584  El proyecto buscará fortalecer las capacidades...
# 5836  Global Health Innovative Technology – Research...
# 5837  Access and Delivery Partnership (Scale-up) - A...
#
#                                      project_descr_long      crs  ...  \
# 30    The COVID-19 Response Mechanism supports count...  12262.0  ...
# 56    La subvention tuberculose et VIH  (2021-2023) ...  12263.0  ...
# 423   Le projet a pour objectif de lutter contre les...  12263.0  ...
# 793   The capacity strengthening plan aims to achiev...  12262.0  ...
# 1776                                                NaN  12262.0  ...
# 1777                                                NaN  12262.0  ...
# 2047  To provide technical assistance to Indonesia’s...  12262.0  ...
# 2300  GLOBAL FUND SECRETARIAT CCM FUNDING to support...  12263.0  ...
# 3173  The main goal of the project is to decrease TB...  12263.0  ...
# 4271  Component 1 - Strengthening of oversight funct...  12262.0  ...
# 4276  Improving and performing public procurement, s...  12263.0  ...
# 4298  Improving and performing public procurement, s...  12263.0  ...
# 4302  Improving and performing public procurement, s...  12263.0  ...
# 4343  Procurement support services to the Republican...  12262.0  ...
# 4466  Disminuir la alta carga de la tuberculosis y s...  12263.0  ...
# 5572  El proyecto persigue fortalecer las capacidade...  12263.0  ...
# 5584  El proyecto buscará fortalecer las capacidades...  12263.0  ...
# 5836  A public-private partnership supported by the ...  12262.0  ...
# 5837  Accelerating access to and delivery of new hea...  12262.0  ...
#
#                                 crs_final_4thplace_desc  crs_final_5thplace  \
# 30    facilitation of orderly, safe, regular and res...             13040.0
# 56                       std control including hiv/aids             31210.0
# 423       forestry policy and administrative management             12182.0
# 793                      std control including hiv/aids             13081.0
# 1776                              sectors not specified             99810.0
# 1777  communications policy and administrative manag...             33181.0
# 2047                     std control including hiv/aids             41082.0
# 2300                     std control including hiv/aids             22010.0
# 3173                           trade education/training             72050.0
# 4271                               tuberculosis control             13030.0
# 4276             other prevention and treatment of ncds             15250.0
# 4298  decentralisation and support to subnational go...             12263.0
# 4302             other prevention and treatment of ncds             15250.0
# 4343                               tuberculosis control             99810.0
# 4466  social services (incl youth development and wo...             23620.0
# 5572               agricultural alternative development             25020.0
# 5584  fossil fuel electric power plants with carbon ...             99810.0
# 5836  energy generation, renewable sources - multipl...             12182.0
# 5837                               tuberculosis control              1511.0
#
#                                 crs_final_5thplace_desc  \
# 30                       std control including hiv/aids
# 56        forestry policy and administrative management
# 423                                    medical research
# 793   personnel development for population and repro...
# 1776                              sectors not specified
# 1777                           trade education/training
# 2047                             environmental research
# 2300  communications policy and administrative manag...
# 3173          relief co-ordination and support services
# 4271                                    family planning
# 4276  removal of land mines and explosive remnants o...
# 4298                               tuberculosis control
# 4302  removal of land mines and explosive remnants o...
# 4343                              sectors not specified
# 4466                       district heating and cooling
# 5572                                      privatisation
# 5584                              sectors not specified
# 5836                                   medical research
# 5837                            debt and aid management
#
#                                          crs_final_desc  match_score  \
# 30                                     low-cost housing       66.000
# 56    social protection and welfare services policy,...       61.425
# 423                                tuberculosis control       65.250
# 793                       livestock/veterinary services       43.500
# 1776  administration of developing countries' foreig...       59.500
# 1777  administration of developing countries' foreig...       57.925
# 2047                         general personnel services       54.750
# 2300  administration of developing countries' foreig...       54.600
# 3173                 national monitoring and evaluation       53.250
# 4271                     std control including hiv/aids       53.200
# 4276        research for prevention and control of ncds       52.500
# 4298  removal of land mines and explosive remnants o...       51.250
# 4302        research for prevention and control of ncds       52.500
# 4343                                             police       46.500
# 4466                                tobacco use control       37.000
# 5572                                          elections       57.505
# 5584                               tuberculosis control       42.000
# 5836             technological research and development       74.025
# 5837                                    malaria control       45.000
#
#       title_score desc_score  desc_l_score desc_c_score    COVID
# 30            NaN        NaN          88.0          NaN  12264.0
# 56            NaN       31.0           NaN         49.0      NaN
# 423           NaN        NaN          87.0          NaN      NaN
# 793           NaN        NaN          58.0          NaN  12264.0
# 1776          NaN       32.0           NaN         45.0  12264.0
# 1777          NaN       31.0           NaN         44.0  12264.0
# 2047          NaN        NaN          73.0          NaN  12264.0
# 2300          NaN        NaN          48.0         42.0      NaN
# 3173          NaN        NaN          71.0          NaN      NaN
# 4271          NaN        NaN          44.0         43.0  12264.0
# 4276          NaN       42.0           NaN          NaN      NaN
# 4298          NaN       41.0           NaN          NaN      NaN
# 4302          NaN       42.0           NaN          NaN      NaN
# 4343          NaN        NaN          62.0          NaN  12264.0
# 4466         74.0        NaN           NaN          NaN      NaN
# 5572         30.8        NaN          37.0         39.0      NaN
# 5584          NaN        NaN          56.0          NaN      NaN
# 5836         89.0       49.0           NaN          NaN  12264.0
# 5837          NaN        NaN          60.0          NaN  12264.0
#
# [19 rows x 30 columns]

# %%
output_file_deduped[['output','fiscal_year','project_title','crs_result','crs_final','crs_final_2ndplace','crs','title_score','desc_score','desc_c_score','desc_l_score','match_score','crs_final_desc']].loc[i]
# Out:
# output                                        81278
# fiscal_year                                    2021
# project_title             Development Effectiveness
# crs_result                                    25030
# crs_final                                     25030
# crs_final_2ndplace                            99820
# crs                                           91010
# title_score                                      71
# desc_score                                      NaN
# desc_c_score                                    NaN
# desc_l_score                                    NaN
# match_score                                      71
# crs_final_desc        business development services
# Name: 99, dtype: object

# %%
output_file_deduped[['fiscal_year','project_title','crs_final_desc','crs_result','crs_final','crs','title_score','desc_score','desc_c_score','desc_l_score','match_score']].loc[ (output_file_deduped['match_score']>0 )]
# Out:
#     fiscal_year                   project_title  \
# 0          2021          IONA CONSERVATION/ GEF
# 1          2021  Support Enhancemen Human Right
# 2          2021   Sust Econ Dev Inclusive Gowth
# 3          2021   Expansion  Strengthening of A
# 4          2021      LDCF/Adaptation Cuvelai RB
# ..          ...                             ...
# 95         2021     COV02 BEN-00125781 MPTF R2R
# 96         2021  BEN COVID-19 Demat Admin Proce
# 97         2021   Appui Institutionnel ADSC TEF
# 98         2021   Promotion Droits Handicapés 2
# 99         2021       Development Effectiveness
#
#                                        crs_final_desc  crs_result  crs_final  \
# 0      energy conservation and demand-side efficiency     23183.0    23183.0
# 1                                        human rights     15160.0    15160.0
# 2                                     postal services      2201.0    22012.0
# 3              other prevention and treatment of ncds     12350.0    12350.0
# 4                    urban land policy and management      4303.0    43031.0
# ..                                                ...         ...        ...
# 95  social protection and welfare services policy,...      1601.0    16011.0
# 96                       district heating and cooling     23620.0    23620.0
# 97  personnel development for population and repro...     13081.0    13081.0
# 98                           trade education/training     33181.0    33181.0
# 99                      business development services     25030.0    25030.0
#
#         crs  title_score  desc_score  desc_c_score  desc_l_score  match_score
# 0   41010.0         80.3         NaN           NaN           NaN       80.300
# 1   15131.0         96.0         NaN           NaN           NaN       96.000
# 2   16050.0          NaN         NaN           NaN          58.0       49.300
# 3   41010.0         60.0         NaN           NaN           NaN       60.000
# 4   41010.0          NaN         NaN           NaN          91.0       77.350
# ..      ...          ...         ...           ...           ...          ...
# 95  16050.0          NaN        46.0          46.0           NaN       64.400
# 96  16062.0          NaN         NaN          48.0           NaN       48.000
# 97  16050.0          NaN        38.0          45.0           NaN       58.100
# 98  15131.0          NaN         NaN          48.0          45.0       60.375
# 99  91010.0         71.0         NaN           NaN           NaN       71.000
#
# [100 rows x 11 columns]

# %%
output_file['project_descr_long'][i] ==output_file['project_descr_long'][i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1b8fc7fa6077> in <module>
# ----> 1 output_file['project_descr_long'][i] ==output_file['project_descr_long'][i]
#
# NameError: name 'output_file' is not defined

# %%
df_result = pd.merge(crs_file,pd.DataFrame(result,columns=['description','descr_score']), 
             how='left', on='description')

# %%
df_result = pd.merge(df_result,pd.DataFrame(result,columns=['description','title_score']), 
             how='left', on='description')

# %%
df_result = pd.merge(df_result,pd.DataFrame(result,columns=['description','descr_l_score']), 
             how='left', on='description')

# %%
df_result[df_result['total_score']>0]

# %%
df_result[(df_result['descr_score'].isnull() == False) | 
              (df_result['title_score'].isnull() == False) | 
              (df_result['descr_c_score'].isnull() == False) | 
              (df_result['descr_l_score'].isnull() == False)]

# %%
pd.DataFrame(result,columns=[desc_col,'descr_score'])

# %%
if detect(output_file_deduped['project_descr'][i]) =='fr':
    desc = crs_desc_l_fr
    desc_col = 'description_fr'
else:
    desc = crs_desc_l
    desc_col = 'description'

result = process.extract(output_file_deduped['project_descr'][i], desc, scorer=fuzz.token_sort_ratio)
df_result = pd.merge(crs_full_file,pd.DataFrame(result,columns=[desc_col,'descr_score']), 
         how='left', on=desc_col)

# %%
#title checker agains desc
if detect(output_file_deduped['project_title'][i]) =='fr':
    desc = crs_desc_l_fr
    desc_col = 'description_fr'
else:
    desc = crs_desc_l
    desc_col = 'description'

result = process.extract(output_file_deduped['project_title'][i], desc, scorer=fuzz.partial_ratio)
df_result = pd.merge(df_result,pd.DataFrame(result,columns=[desc_col,'title_score']), 
         how='left', on=desc_col)

#deduct score if title word not in description
title_list =  re.sub("[^\w]", " ",  output_file_deduped['project_title'][i].lower()).split()
df_result['title_score']=df_result.loc[df_result['title_score']>=0].apply(lambda y:  y['title_score'] if any(x in y['description'] for x in title_list) else y['title_score']*.5, axis=1)

#evaluate project descr against clarification
#description checker agains desc
if detect(output_file_deduped['project_descr'][i]) =='fr':
    clari = crs_clari_l_fr
    clari_col = 'clarification_fr'
else:
    clari = crs_clari_l
    clari_col = 'clarification'

result = process.extract(output_file_deduped['project_descr'][i], clari, scorer=fuzz.token_set_ratio)
df_result = pd.merge(df_result,pd.DataFrame(result,columns=[clari_col,'descr_c_score']), 
         how='left', on=clari_col)

if output_file_deduped['project_descr_long'][i]==output_file_deduped['project_descr_long'][i]:
    #long description checker agains desc
    if detect(output_file_deduped['project_descr_long'][i]) =='fr':
        clari = crs_clari_l_fr
        clari_col = 'clarification_fr'
    else:
        clari = crs_clari_l
        clari_col = 'clarification'

    result = process.extract(output_file_deduped['project_descr_long'][i], clari, scorer=fuzz.token_set_ratio)
    df_result = pd.merge(df_result,pd.DataFrame(result,columns=[clari_col,'descr_l_score']), 
         how='left', on=clari_col)
else:
    df_result['descr_l_score'] = math.nan

df_result['total_score'] = df_result['descr_score'].fillna(0) + df_result['title_score'].fillna(0) + \
            df_result['descr_l_score'].fillna(0) + df_result['descr_c_score'].fillna(0)

df_result.loc[(df_result['descr_score'].isnull() == False) & 
              (df_result['descr_c_score'].isnull() == False) & 
              (df_result['title_score'].isnull() == False) & 
              (df_result['descr_l_score'].isnull() == False),'total_score'] = df_result['total_score']*1.1


df_result.loc[((df_result['descr_score'].isnull() == False) & 
              (df_result['title_score'].isnull() == False)) |
              ((df_result['title_score'].isnull() == False) &
              (df_result['descr_score'].isnull() == False)) |
              ((df_result['descr_score'].isnull() == False) &
              (df_result['descr_l_score'].isnull() == False)) |
              ((df_result['descr_score'].isnull() == False) &
              (df_result['descr_c_score'].isnull() == False)) |
              ((df_result['title_score'].isnull() == False) &
              (df_result['descr_c_score'].isnull() == False)) |
              ((df_result['descr_l_score'].isnull() == False) &
              (df_result['descr_c_score'].isnull() == False)),'total_score'] = df_result['total_score']*1.05

df_result.loc[(df_result['crs']>0) & 
          (df_result['crs']==output_file_deduped['crs'][i]) & 
          (df_result['crs']!=99810),'total_score'] = df_result['total_score']*1.35

output_file_deduped.at[i,'dac5_result'] = df_result.loc[df_result['total_score'].argmax()]['dac5']
output_file_deduped.at[i,'crs_result'] = df_result.loc[df_result['total_score'].argmax()]['crs']
output_file_deduped.at[i,'volunt_result'] = df_result.loc[df_result['total_score'].argmax()]['voluntary']

if math.isnan(df_result.loc[df_result['total_score'].argmax()]['voluntary'])==False:
    crs_final = df_result.loc[df_result['total_score'].argmax()]['voluntary']
elif math.isnan(df_result.loc[df_result['total_score'].argmax()]['crs'])==False:
    crs_final = df_result.loc[df_result['total_score'].argmax()]['crs']
elif math.isnan(df_result.loc[df_result['total_score'].argmax()]['dac5'])==False:
    crs_final = df_result.loc[df_result['total_score'].argmax()]['dac5']

output_file_deduped.at[i,'crs_final'] = crs_final
output_file_deduped.at[i,'crs_final_2ndplace'] = df_result.loc[df_result['total_score'].nlargest(2).index.tolist()[1]]['crs']
output_file_deduped.at[i,'crs_final_desc'] = df_result.loc[df_result['total_score'].argmax()]['description']
output_file_deduped.at[i,'match_score'] = df_result.loc[df_result['total_score'].argmax()]['total_score']
output_file_deduped.at[i,'title_score'] = df_result.loc[df_result['total_score'].argmax()]['title_score']
output_file_deduped.at[i,'desc_score'] = df_result.loc[df_result['total_score'].argmax()]['descr_score']
output_file_deduped.at[i,'desc_l_score'] = df_result.loc[df_result['total_score'].argmax()]['descr_l_score']
output_file_deduped.at[i,'desc_c_score'] = df_result.loc[df_result['total_score'].argmax()]['descr_c_score']

# %%
df_result
# Out:
#       dac5      crs  voluntary  \
# 0    111.0  11110.0        NaN
# 1    111.0  11120.0        NaN
# 2    111.0  11130.0        NaN
# 3    111.0  11182.0        NaN
# 4    112.0  11220.0        NaN
# ..     ...      ...        ...
# 290  930.0   9301.0    93016.0
# 291  930.0   9301.0    93017.0
# 292  930.0   9301.0    93018.0
# 293  998.0  99810.0        NaN
# 294  998.0  99820.0        NaN
#
#                                            description  \
# 0       education policy and administrative management
# 1                    education facilities and training
# 2                                     teacher training
# 3                                 educational research
# 4                                    primary education
# ..                                                 ...
# 290  refugees/asylum seekers in donor countries - t...
# 291  refugees/asylum seekers in donor countries - r...
# 292  refugees/asylum seekers in donor countries - a...
# 293                              sectors not specified
# 294  promotion of development awareness (non-sector...
#
#                                          clarification  \
# 0    education sector policy, planning and programm...
# 1    educational buildings, equipment, materials; s...
# 2    teacher education (where the level of educatio...
# 3    research and studies on education effectivenes...
# 4    formal and non-formal primary education for ch...
# ..                                                 ...
# 290  costs incurred in donor countries for basic as...
# 291  costs incurred in donor countries for basic as...
# 292  costs incurred in donor countries for basic as...
# 293  contributions to general development of the re...
# 294  spending in donor country for heightened aware...
#
#                                         description_fr  \
# 0    politique de l’éducation et gestion administra...
# 1                   equipements scolaires et formation
# 2                            formation des enseignants
# 3                               recherche en éducation
# 4                                enseignement primaire
# ..                                                 ...
# 290  refugiés/demandeurs d’asile dans les pays donn...
# 291  refugiés/demandeurs d’asile dans les pays donn...
# 292  refugiés/demandeurs d’asile dans les pays donn...
# 293                               secteur non spécifié
# 294  sensibilisation au développement (non alloués ...
#
#                                       clarification_fr  descr_score  \
# 0    politique de l’éducation, planification et pro...          NaN
# 1    bâtiments scolaires, équipement, fournitures ;...          NaN
# 2    éducation des enseignants (quand le niveau d’é...          NaN
# 3    recherche et études sur l’efficacité, la perti...          NaN
# 4    enseignement primaire formel et non formel pou...          NaN
# ..                                                 ...          ...
# 290  coûts encourus dans les pays donneurs au titre...          NaN
# 291  coûts encourus dans les pays donneurs au titre...          NaN
# 292  coûts encourus dans les pays donneurs au titre...          NaN
# 293  les contributions au développement général du ...          NaN
# 294  dépenses dans le pays donneur afin de renforce...          NaN
#
#      title_score  descr_c_score  descr_l_score  total_score
# 0            NaN            NaN            NaN          0.0
# 1            NaN            NaN            NaN          0.0
# 2            NaN            NaN            NaN          0.0
# 3            NaN            NaN            NaN          0.0
# 4            NaN            NaN            NaN          0.0
# ..           ...            ...            ...          ...
# 290          NaN            NaN            NaN          0.0
# 291          NaN            NaN            NaN          0.0
# 292          NaN            NaN            NaN          0.0
# 293          NaN            NaN            NaN          0.0
# 294          NaN            NaN            NaN          0.0
#
# [295 rows x 12 columns]
